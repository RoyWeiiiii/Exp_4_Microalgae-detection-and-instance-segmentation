# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
import torch # YOLOv5 implemented using pytorch

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 28.9/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2/dataset/2

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 151MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB/data.yaml
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:09<00:00,  4.07it/s]
#                    all        630      10359      0.866      0.873      0.918      0.731
#                    C.R        210       3116      0.848      0.853      0.914      0.688
#                    C.V        210       6435      0.954      0.968      0.989      0.802
#                    S.P        210        808      0.797      0.798      0.849      0.703
# Speed: 0.3ms preprocess, 1.4ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/detect/val
# ...

# %% [markdown]
# Testing the model

# %%
# !yolo task=detect mode= predict model= /content/runs/detect/train/weights/best.pt conf=0.25 source= /content/runs/detect/predict
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/60 /content/runs/detect/predict/Chlamy0000.jpg: 512x512 12 C.Rs, 1 C.V, 8.5ms
# image 2/60 /content/runs/detect/predict/Chlamy0001.jpg: 512x512 14 C.Rs, 7.2ms
# image 3/60 /content/runs/detect/predict/Chlamy0002.jpg: 512x512 30 C.Rs, 6.7ms
# image 4/60 /content/runs/detect/predict/Chlamy0003.jpg: 512x512 18 C.Rs, 7.0ms
# image 5/60 /content/runs/detect/predict/Chlamy0004.jpg: 512x512 23 C.Rs, 6.7ms
# image 6/60 /content/runs/detect/predict/Chlamy0005.jpg: 512x512 28 C.Rs, 7.8ms
# image 7/60 /content/runs/detect/predict/Chlamy0006.jpg: 512x512 24 C.Rs, 6.7ms
# image 8/60 /content/runs/detect/predict/Chlamy0007.jpg: 512x512 21 C.Rs, 6.9ms
# image 9/60 /content/runs/detect/predict/Chlamy0008.jpg: 512x512 28 C.Rs, 7.1ms
# ...
