# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
import torch # YOLOv5 implemented using pytorch

# %%
from IPython.display import Image #this is to render predictions

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16575, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 16575 (delta 28), reused 37 (delta 18), pack-reused 16522
# Receiving objects: 100% (16575/16575), 15.10 MiB | 15.81 MiB/s, done.
# Resolving deltas: 100% (11385/11385), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# install dependencies as necessary
# !pip install -r requirements.txt  # install dependencies (ignore errors)
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Microalgae_Detection_yoloV5_trial_6/data.yaml
# Out:
# train: /content/drive/MyDrive/Microalgae_Detection_yoloV5_trial_6/train
# val: /content/drive/MyDrive/Microalgae_Detection_yoloV5_trial_6/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2/dataset/2

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
# %%time
# %cd /content/yolov5/
# !python train.py --img 512 --batch 16 --epochs 50 --data /content/drive/MyDrive/Microalgae_Detection_yoloV5_trial_6/data.yaml --weights yolov5s.pt --name yolov5s_results  --cache
# Out:
# /content/yolov5
# 2024-05-02 07:04:21.690671: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 07:04:21.690732: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 07:04:21.692123: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %% [markdown]
# Testing the model

# %%
# %cd /content/yolov5/
# !python detect.py
# !https://github.com/ultralytics/yolov5/blob/master/detect.py --weights /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt --img 512 --conf 0.4 --source /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# [Errno 2] No such file or directory: '/content/yolov5/'
# /content
# /bin/bash: line 1: https://github.com/ultralytics/yolov5/blob/master/detect.py: No such file or directory

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
