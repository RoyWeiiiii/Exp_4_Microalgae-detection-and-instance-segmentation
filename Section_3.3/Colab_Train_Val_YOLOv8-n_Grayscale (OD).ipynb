# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2/dataset/3

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 182MB/s]
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 43.6MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/train/labels... 2520 images, 1 backgrounds, 0 corrupt: 100% 2520/2520 [04:12<00:00,  9.97it/s]
# train: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/valid/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [01:01<00:00, 10.22it/s]
# val: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50       2.3G      1.375      1.878      1.034        172        512: 100% 158/158 [00:26<00:00,  5.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.98it/s]
#                    all        630      10359      0.701      0.693      0.724      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.06G      1.205      1.209      1.008        224        512: 100% 158/158 [00:17<00:00,  8.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.60it/s]
#                    all        630      10359      0.677       0.68      0.708       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.43G      1.171      1.092     0.9914        240        512: 100% 158/158 [00:17<00:00,  9.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.85it/s]
#                    all        630      10359       0.71      0.766      0.747      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.25G      1.162      1.032     0.9862         96        512: 100% 158/158 [00:17<00:00,  9.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.61it/s]
#                    all        630      10359      0.624      0.667      0.727       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.08G      1.123     0.9915     0.9804        155        512: 100% 158/158 [00:17<00:00,  9.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.54it/s]
#                    all        630      10359      0.742      0.775      0.798      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.63G      1.119     0.9383     0.9837        116        512: 100% 158/158 [00:16<00:00,  9.38it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.50it/s]
#                    all        630      10359      0.655      0.758      0.723      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.27G      1.096     0.9294     0.9778        198        512: 100% 158/158 [00:17<00:00,  9.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.89it/s]
#                    all        630      10359      0.664      0.651      0.702      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.44G      1.086     0.9185     0.9726         74        512: 100% 158/158 [00:17<00:00,  9.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.82it/s]
#                    all        630      10359      0.714      0.612      0.731      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50       2.8G      1.083     0.8813     0.9691        149        512: 100% 158/158 [00:17<00:00,  9.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.18it/s]
#                    all        630      10359      0.756      0.815      0.827      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.08G      1.055     0.8678     0.9734        189        512: 100% 158/158 [00:17<00:00,  9.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.00it/s]
#                    all        630      10359       0.75      0.784       0.82      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.08G      1.044     0.8566     0.9551        149        512: 100% 158/158 [00:17<00:00,  9.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.58it/s]
#                    all        630      10359       0.76      0.807      0.841      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50       3.1G      1.024      0.821     0.9498        143        512: 100% 158/158 [00:17<00:00,  9.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.40it/s]
#                    all        630      10359      0.757      0.796      0.835       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.28G      1.017     0.8069     0.9537        114        512: 100% 158/158 [00:17<00:00,  9.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.40it/s]
#                    all        630      10359      0.789      0.799      0.851      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.42G      1.025     0.7989     0.9451        166        512: 100% 158/158 [00:17<00:00,  9.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.84it/s]
#                    all        630      10359      0.798      0.829      0.868      0.629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.47G      1.006     0.7925     0.9458         93        512: 100% 158/158 [00:17<00:00,  9.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.21it/s]
#                    all        630      10359       0.72      0.542      0.735      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.07G      1.007     0.7914      0.945         96        512: 100% 158/158 [00:16<00:00,  9.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.20it/s]
#                    all        630      10359      0.793      0.834      0.858      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.38G      1.002     0.7852      0.942         97        512: 100% 158/158 [00:17<00:00,  9.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.46it/s]
#                    all        630      10359      0.786      0.796      0.841      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.46G     0.9988     0.7843     0.9442         95        512: 100% 158/158 [00:17<00:00,  8.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.75it/s]
#                    all        630      10359      0.793      0.817      0.865       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.36G     0.9855      0.766     0.9399        160        512: 100% 158/158 [00:17<00:00,  9.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.53it/s]
#                    all        630      10359      0.791      0.842      0.874      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.15G     0.9826     0.7548     0.9373        154        512: 100% 158/158 [00:17<00:00,  9.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.45it/s]
#                    all        630      10359      0.798      0.849      0.877      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.45G     0.9792     0.7383     0.9369        219        512: 100% 158/158 [00:17<00:00,  9.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.63it/s]
#                    all        630      10359      0.808      0.843      0.882      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.63G      0.979     0.7632     0.9457        159        512: 100% 158/158 [00:17<00:00,  9.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.86it/s]
#                    all        630      10359      0.804      0.847      0.881      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50       2.6G     0.9558     0.7358     0.9345         77        512: 100% 158/158 [00:17<00:00,  9.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.05it/s]
#                    all        630      10359      0.786      0.848      0.869      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      1.93G     0.9664     0.7443     0.9352        144        512: 100% 158/158 [00:17<00:00,  9.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.04it/s]
#                    all        630      10359      0.812      0.859      0.881      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50       2.2G     0.9522     0.7205     0.9271        224        512: 100% 158/158 [00:17<00:00,  9.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.98it/s]
#                    all        630      10359      0.784      0.794      0.851      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.53G     0.9633     0.7435     0.9355        150        512: 100% 158/158 [00:17<00:00,  9.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.74it/s]
#                    all        630      10359       0.81      0.831      0.873       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.22G     0.9448     0.7087     0.9272        109        512: 100% 158/158 [00:16<00:00,  9.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.60it/s]
#                    all        630      10359      0.804      0.853       0.87      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.73G     0.9512     0.7212     0.9338        186        512: 100% 158/158 [00:17<00:00,  9.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.13it/s]
#                    all        630      10359      0.815       0.85      0.883      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.09G     0.9448     0.7075     0.9251        143        512: 100% 158/158 [00:16<00:00,  9.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.99it/s]
#                    all        630      10359      0.832      0.853      0.896      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.11G     0.9393     0.7224     0.9281        123        512: 100% 158/158 [00:17<00:00,  9.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.00it/s]
#                    all        630      10359      0.781      0.843      0.855      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.93G     0.9278     0.7046     0.9284        113        512: 100% 158/158 [00:17<00:00,  9.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.13it/s]
#                    all        630      10359       0.82      0.854      0.888       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.53G     0.9228     0.6908      0.921        258        512: 100% 158/158 [00:17<00:00,  9.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.95it/s]
#                    all        630      10359      0.826       0.86      0.898      0.685
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.42G     0.9182     0.6982     0.9212        136        512: 100% 158/158 [00:17<00:00,  9.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.00it/s]
#                    all        630      10359      0.839       0.85      0.902       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.31G     0.9203     0.7099     0.9297        152        512: 100% 158/158 [00:17<00:00,  9.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.63it/s]
#                    all        630      10359      0.817      0.867      0.895      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.14G     0.9148     0.6817     0.9181        235        512: 100% 158/158 [00:16<00:00,  9.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.61it/s]
#                    all        630      10359      0.829      0.873      0.899      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.97G      0.903     0.6688     0.9164        174        512: 100% 158/158 [00:17<00:00,  9.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.73it/s]
#                    all        630      10359      0.834      0.851      0.894      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.04G     0.8991     0.6761     0.9168         97        512: 100% 158/158 [00:17<00:00,  9.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.04it/s]
#                    all        630      10359       0.83      0.866      0.899      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      2.28G     0.8914     0.6595     0.9137         89        512: 100% 158/158 [00:17<00:00,  9.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.08it/s]
#                    all        630      10359      0.836      0.857      0.894      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.16G     0.9051     0.6813     0.9233        154        512: 100% 158/158 [00:18<00:00,  8.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.18it/s]
#                    all        630      10359      0.835      0.859      0.899       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.07G      0.891      0.662     0.9173        144        512: 100% 158/158 [00:17<00:00,  9.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.99it/s]
#                    all        630      10359      0.846      0.856        0.9      0.692
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.02G     0.8715      0.596     0.8897        130        512: 100% 158/158 [00:21<00:00,  7.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.35it/s]
#                    all        630      10359      0.843      0.868      0.902      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.16G      0.861     0.5907     0.8906        140        512: 100% 158/158 [00:16<00:00,  9.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.63it/s]
#                    all        630      10359      0.845      0.865      0.906      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.16G      0.862     0.5853     0.8882         46        512: 100% 158/158 [00:16<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.98it/s]
#                    all        630      10359      0.844      0.869      0.907      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.06G     0.8525     0.5718     0.8846         70        512: 100% 158/158 [00:16<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.17it/s]
#                    all        630      10359      0.855      0.869      0.908      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.05G     0.8474      0.562     0.8773        187        512: 100% 158/158 [00:16<00:00,  9.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.31it/s]
#                    all        630      10359      0.851      0.867      0.909      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.79G     0.8366     0.5581     0.8784         73        512: 100% 158/158 [00:16<00:00,  9.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630      10359      0.852      0.868      0.907      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.98G     0.8303     0.5524     0.8791        143        512: 100% 158/158 [00:16<00:00,  9.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630      10359      0.848      0.876       0.91      0.717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.23G     0.8323     0.5549     0.8759        122        512: 100% 158/158 [00:16<00:00,  9.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.98it/s]
#                    all        630      10359      0.852      0.868       0.91      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.14G     0.8276     0.5495      0.881        118        512: 100% 158/158 [00:16<00:00,  9.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.61it/s]
#                    all        630      10359      0.849       0.88      0.914      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.26G     0.8249     0.5358     0.8773        141        512: 100% 158/158 [00:17<00:00,  9.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.58it/s]
#                    all        630      10359      0.859      0.874      0.914      0.723
#
# 50 epochs completed in 0.300 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:12<00:00,  1.61it/s]
#                    all        630      10359      0.859      0.874      0.914      0.723
#                    C.R        630       3116      0.836      0.853       0.91      0.688
#                    C.V        630       6435      0.952      0.964      0.988      0.788
#                    S.P        630        808      0.789      0.806      0.845      0.694
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 19.6 s, sys: 2.37 s, total: 22 s
# Wall time: 24min 18s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/data.yaml
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Grayscale/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:12<00:00,  3.23it/s]
#                    all        630      10359      0.859      0.874      0.914      0.726
#                    C.R        630       3116      0.835      0.852       0.91      0.688
#                    C.V        630       6435      0.952      0.964      0.988      0.796
#                    S.P        630        808      0.791      0.806      0.845      0.694
# Speed: 0.3ms preprocess, 1.3ms inference, 0.0ms loss, 4.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
