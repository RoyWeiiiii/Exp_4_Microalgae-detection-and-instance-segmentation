# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 28.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2
#   version: 8
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2/dataset/8

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 75.9MB/s]
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 17.4MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/train/labels... 2520 images, 1 backgrounds, 0 corrupt: 100% 2520/2520 [03:31<00:00, 11.91it/s]
# train: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/valid/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [01:17<00:00,  8.18it/s]
# val: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50       2.3G      1.373      1.884      1.032        165        512: 100% 158/158 [00:25<00:00,  6.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.03it/s]
#                    all        630       9958      0.667      0.728      0.708      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.97G      1.229      1.194      1.007        136        512: 100% 158/158 [00:17<00:00,  9.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.44it/s]
#                    all        630       9958      0.679      0.743      0.748      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.36G      1.193      1.086     0.9881        241        512: 100% 158/158 [00:16<00:00,  9.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.81it/s]
#                    all        630       9958      0.665      0.707      0.711      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.47G      1.166      1.028     0.9831         72        512: 100% 158/158 [00:16<00:00,  9.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.28it/s]
#                    all        630       9958      0.588      0.797      0.753      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50       2.8G      1.143     0.9793     0.9745        153        512: 100% 158/158 [00:16<00:00,  9.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.75it/s]
#                    all        630       9958      0.692      0.725      0.756      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.62G      1.139     0.9351     0.9705        109        512: 100% 158/158 [00:16<00:00,  9.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.89it/s]
#                    all        630       9958      0.613      0.722      0.684      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.02G      1.115     0.9267     0.9763        154        512: 100% 158/158 [00:16<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.65it/s]
#                    all        630       9958      0.674      0.736      0.747      0.495
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50       2.3G      1.101     0.8987     0.9706         84        512: 100% 158/158 [00:16<00:00,  9.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.15it/s]
#                    all        630       9958      0.708      0.753      0.775      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.51G      1.093      0.875     0.9665        125        512: 100% 158/158 [00:16<00:00,  9.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.46it/s]
#                    all        630       9958       0.68      0.813      0.789      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.29G      1.062      0.852     0.9662        273        512: 100% 158/158 [00:16<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.57it/s]
#                    all        630       9958      0.739       0.81      0.822      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.27G      1.061     0.8564     0.9604         82        512: 100% 158/158 [00:16<00:00,  9.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630       9958      0.693      0.757      0.785      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.01G       1.05     0.8335     0.9552        157        512: 100% 158/158 [00:16<00:00,  9.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.24it/s]
#                    all        630       9958      0.736      0.806      0.824       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.24G      1.044     0.8002     0.9485        103        512: 100% 158/158 [00:16<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.11it/s]
#                    all        630       9958      0.751      0.793      0.819      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.94G      1.057     0.8116     0.9501        163        512: 100% 158/158 [00:16<00:00,  9.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.84it/s]
#                    all        630       9958      0.729      0.811      0.821      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.28G      1.032     0.7928     0.9482        103        512: 100% 158/158 [00:16<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.77it/s]
#                    all        630       9958      0.744      0.773      0.819      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.14G      1.012     0.7817     0.9459        171        512: 100% 158/158 [00:16<00:00,  9.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958       0.74      0.813      0.821      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50       2.7G     0.9976     0.7767     0.9404        177        512: 100% 158/158 [00:16<00:00,  9.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.48it/s]
#                    all        630       9958      0.639      0.752      0.761       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.18G      1.007     0.7746      0.939        126        512: 100% 158/158 [00:16<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.39it/s]
#                    all        630       9958      0.767      0.811      0.836      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.18G     0.9962     0.7605     0.9392        188        512: 100% 158/158 [00:16<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.19it/s]
#                    all        630       9958      0.783      0.794      0.841      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.28G     0.9951     0.7668     0.9367        151        512: 100% 158/158 [00:16<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.42it/s]
#                    all        630       9958      0.768      0.798      0.834      0.579
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.69G     0.9944     0.7608      0.936        250        512: 100% 158/158 [00:16<00:00,  9.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.30it/s]
#                    all        630       9958      0.736      0.817      0.826      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      1.74G     0.9848     0.7509     0.9399        147        512: 100% 158/158 [00:16<00:00,  9.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.09it/s]
#                    all        630       9958      0.754      0.825      0.835       0.61
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      3.05G       0.97     0.7338     0.9341         79        512: 100% 158/158 [00:16<00:00,  9.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.85it/s]
#                    all        630       9958      0.765      0.812      0.834      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.36G     0.9667     0.7218     0.9303        271        512: 100% 158/158 [00:16<00:00,  9.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.21it/s]
#                    all        630       9958      0.776      0.798      0.843      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.92G      0.967     0.7204      0.934         69        512: 100% 158/158 [00:16<00:00,  9.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.37it/s]
#                    all        630       9958      0.735      0.787      0.828      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.45G     0.9672     0.7268     0.9307        135        512: 100% 158/158 [00:16<00:00,  9.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.40it/s]
#                    all        630       9958      0.778      0.762      0.833      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.63G     0.9661     0.7151     0.9324        113        512: 100% 158/158 [00:16<00:00,  9.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.38it/s]
#                    all        630       9958      0.799      0.834      0.858      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.48G     0.9676      0.722     0.9321        157        512: 100% 158/158 [00:16<00:00,  9.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.45it/s]
#                    all        630       9958      0.767       0.83      0.848      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.13G     0.9529     0.7117     0.9267         95        512: 100% 158/158 [00:16<00:00,  9.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.09it/s]
#                    all        630       9958      0.769      0.847      0.855      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.74G      0.948     0.6951     0.9255        104        512: 100% 158/158 [00:16<00:00,  9.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.08it/s]
#                    all        630       9958      0.778      0.838      0.849      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.65G      0.946     0.7042     0.9254        122        512: 100% 158/158 [00:16<00:00,  9.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.76it/s]
#                    all        630       9958      0.797      0.816      0.858      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.83G     0.9373     0.6953       0.92        160        512: 100% 158/158 [00:16<00:00,  9.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.08it/s]
#                    all        630       9958      0.784      0.841      0.865      0.625
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.35G     0.9407     0.6856     0.9196        124        512: 100% 158/158 [00:16<00:00,  9.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958      0.791       0.85      0.863      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.16G       0.92     0.6833     0.9177        170        512: 100% 158/158 [00:16<00:00,  9.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.22it/s]
#                    all        630       9958      0.794      0.826      0.858      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.43G     0.9323      0.685     0.9211        193        512: 100% 158/158 [00:16<00:00,  9.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:02<00:00,  6.73it/s]
#                    all        630       9958      0.817      0.821      0.871      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.76G     0.9221     0.6785      0.919        185        512: 100% 158/158 [00:16<00:00,  9.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.30it/s]
#                    all        630       9958      0.775       0.82      0.849      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.79G      0.919     0.6624     0.9166         86        512: 100% 158/158 [00:16<00:00,  9.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.35it/s]
#                    all        630       9958      0.785      0.851      0.868      0.644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      2.72G      0.917     0.6685     0.9155        132        512: 100% 158/158 [00:16<00:00,  9.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.06it/s]
#                    all        630       9958      0.787      0.848      0.868      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.37G      0.911      0.665     0.9195        152        512: 100% 158/158 [00:16<00:00,  9.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.96it/s]
#                    all        630       9958      0.781       0.84      0.863      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.31G     0.9101     0.6674     0.9176        204        512: 100% 158/158 [00:16<00:00,  9.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.07it/s]
#                    all        630       9958      0.792      0.842      0.867      0.645
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.03G     0.8806     0.5916     0.8885        130        512: 100% 158/158 [00:20<00:00,  7.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958      0.822      0.827      0.877      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.17G     0.8728     0.5872     0.8899        122        512: 100% 158/158 [00:15<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.55it/s]
#                    all        630       9958      0.805      0.836      0.866      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.18G     0.8703     0.5803     0.8861         48        512: 100% 158/158 [00:15<00:00,  9.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.47it/s]
#                    all        630       9958      0.819       0.83      0.874      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.08G     0.8637     0.5698     0.8835         70        512: 100% 158/158 [00:15<00:00,  9.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.96it/s]
#                    all        630       9958      0.814      0.841      0.876      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.07G     0.8612     0.5652     0.8788        187        512: 100% 158/158 [00:15<00:00, 10.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.10it/s]
#                    all        630       9958      0.813      0.858      0.883      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50       1.8G     0.8532     0.5615     0.8797         93        512: 100% 158/158 [00:15<00:00,  9.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.00it/s]
#                    all        630       9958      0.812      0.845      0.875      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.84G     0.8444      0.547     0.8799        130        512: 100% 158/158 [00:16<00:00,  9.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.96it/s]
#                    all        630       9958      0.817      0.839      0.876      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.25G     0.8417     0.5497     0.8751        123        512: 100% 158/158 [00:15<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958      0.812      0.849      0.879      0.664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.16G     0.8373     0.5424     0.8764        121        512: 100% 158/158 [00:15<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.61it/s]
#                    all        630       9958      0.818      0.846      0.882       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.28G     0.8318     0.5386     0.8729        129        512: 100% 158/158 [00:15<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.55it/s]
#                    all        630       9958      0.827      0.845      0.883      0.668
#
# 50 epochs completed in 0.287 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  10% 2/20 [00:00<00:03,  4.86it/s]WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:10<00:00,  1.96it/s]
#                    all        630       9958      0.813      0.832      0.863      0.656
#                    C.R        630       2715      0.708      0.848      0.841      0.621
#                    C.V        630       6435      0.942       0.88      0.925      0.691
#                    S.P        630        808      0.789      0.769      0.825      0.655
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 6.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 16.5 s, sys: 2.23 s, total: 18.7 s
# Wall time: 23min 2s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/data.yaml
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_Gray-Histogram/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:14<00:00,  2.77it/s]
#                    all        630       9958      0.814      0.858      0.883      0.673
#                    C.R        630       2715       0.71      0.849      0.841       0.62
#                    C.V        630       6435      0.944      0.955      0.982      0.744
#                    S.P        630        808      0.789      0.769      0.825      0.654
# Speed: 0.3ms preprocess, 1.2ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
