# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4/dataset/3

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 83.1MB/s]
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 18.2MB/s]
# 2024-05-15 14:06:36.053610: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-15 14:06:36.053671: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-15 14:06:36.054949: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/train/labels... 2520 images, 1 backgrounds, 0 corrupt: 100% 2520/2520 [03:30<00:00, 11.99it/s]
# train: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/valid/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:43<00:00, 14.34it/s]
# val: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50       1.6G      1.476      2.316      1.402         76        512: 100% 158/158 [00:22<00:00,  6.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.17it/s]
#                    all        630       5077      0.422      0.475      0.391      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.56G      1.363      1.781       1.34         96        512: 100% 158/158 [00:17<00:00,  9.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.45it/s]
#                    all        630       5077      0.385      0.524      0.422      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50       1.7G      1.362      1.738       1.34        118        512: 100% 158/158 [00:16<00:00,  9.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.88it/s]
#                    all        630       5077      0.405      0.495      0.387      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.72G      1.325      1.655      1.325         56        512: 100% 158/158 [00:16<00:00,  9.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.05it/s]
#                    all        630       5077      0.353      0.507      0.394      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.68G      1.297      1.618      1.321        110        512: 100% 158/158 [00:16<00:00,  9.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.97it/s]
#                    all        630       5077      0.437      0.568      0.472      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.57G      1.273      1.566      1.304         90        512: 100% 158/158 [00:16<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.22it/s]
#                    all        630       5077      0.522      0.521      0.514      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.84G      1.245      1.529      1.285         66        512: 100% 158/158 [00:16<00:00,  9.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.16it/s]
#                    all        630       5077      0.465      0.606      0.541      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.57G       1.23      1.518      1.276        111        512: 100% 158/158 [00:16<00:00,  9.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.88it/s]
#                    all        630       5077      0.472      0.582      0.525      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      1.68G      1.216      1.485      1.274         66        512: 100% 158/158 [00:16<00:00,  9.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.91it/s]
#                    all        630       5077      0.514      0.591      0.541      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.57G      1.192      1.442      1.256         83        512: 100% 158/158 [00:16<00:00,  9.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.06it/s]
#                    all        630       5077      0.512      0.588      0.567      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      1.56G       1.19      1.461      1.255         67        512: 100% 158/158 [00:16<00:00,  9.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.42it/s]
#                    all        630       5077      0.599      0.562      0.567      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      1.57G      1.168      1.426      1.242         56        512: 100% 158/158 [00:16<00:00,  9.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.04it/s]
#                    all        630       5077       0.55      0.565      0.563      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      1.67G       1.17      1.423      1.247         56        512: 100% 158/158 [00:16<00:00,  9.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.09it/s]
#                    all        630       5077      0.606      0.427      0.463      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.71G      1.156      1.382      1.227         68        512: 100% 158/158 [00:16<00:00,  9.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.85it/s]
#                    all        630       5077      0.582      0.579       0.56      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      1.56G      1.145       1.39       1.24         78        512: 100% 158/158 [00:17<00:00,  9.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.62it/s]
#                    all        630       5077      0.451      0.658      0.551      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      1.57G      1.137      1.371      1.229        121        512: 100% 158/158 [00:16<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.95it/s]
#                    all        630       5077      0.546      0.577      0.575      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      1.56G      1.132      1.357      1.218         86        512: 100% 158/158 [00:16<00:00,  9.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.11it/s]
#                    all        630       5077      0.511      0.668        0.6      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      1.57G      1.128      1.366       1.22         76        512: 100% 158/158 [00:16<00:00,  9.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.48it/s]
#                    all        630       5077       0.48      0.662      0.587      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      1.56G      1.119      1.349       1.22         57        512: 100% 158/158 [00:16<00:00,  9.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.58it/s]
#                    all        630       5077      0.512      0.637      0.605      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      1.57G      1.117      1.339      1.219        224        512: 100% 158/158 [00:15<00:00,  9.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.44it/s]
#                    all        630       5077      0.497      0.643      0.603      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50       1.7G      1.105      1.344      1.209         85        512: 100% 158/158 [00:16<00:00,  9.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.41it/s]
#                    all        630       5077      0.558      0.631      0.627      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      1.57G      1.097      1.325      1.216        122        512: 100% 158/158 [00:15<00:00,  9.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.59it/s]
#                    all        630       5077      0.582      0.634      0.636      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      1.69G      1.096      1.329      1.207         54        512: 100% 158/158 [00:15<00:00,  9.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.31it/s]
#                    all        630       5077      0.544      0.655      0.634      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      1.69G      1.087      1.301      1.197        117        512: 100% 158/158 [00:15<00:00, 10.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.19it/s]
#                    all        630       5077      0.569      0.651      0.652      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.56G      1.077      1.295      1.188         88        512: 100% 158/158 [00:15<00:00,  9.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.02it/s]
#                    all        630       5077       0.58      0.622      0.628      0.427
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      1.57G      1.075      1.302      1.192         99        512: 100% 158/158 [00:15<00:00,  9.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.36it/s]
#                    all        630       5077      0.569      0.632      0.618      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.56G      1.069      1.284      1.195        103        512: 100% 158/158 [00:15<00:00,  9.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.64it/s]
#                    all        630       5077      0.532      0.663       0.61       0.43
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      1.83G      1.059      1.266      1.178         80        512: 100% 158/158 [00:16<00:00,  9.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.58it/s]
#                    all        630       5077      0.576      0.638      0.641      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      1.72G      1.067      1.278       1.19         85        512: 100% 158/158 [00:16<00:00,  9.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.50it/s]
#                    all        630       5077      0.532      0.684      0.644      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      1.57G      1.054      1.266      1.181         70        512: 100% 158/158 [00:15<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.48it/s]
#                    all        630       5077      0.615       0.66      0.677      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      1.56G       1.05      1.263      1.185         61        512: 100% 158/158 [00:15<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.55it/s]
#                    all        630       5077      0.614      0.666      0.662      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      1.57G       1.04      1.236       1.17        159        512: 100% 158/158 [00:15<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.14it/s]
#                    all        630       5077      0.637      0.627      0.656      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      1.56G      1.042      1.253      1.175         73        512: 100% 158/158 [00:15<00:00, 10.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.29it/s]
#                    all        630       5077       0.55      0.685       0.65      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      1.57G      1.029       1.22      1.167         93        512: 100% 158/158 [00:15<00:00, 10.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.23it/s]
#                    all        630       5077      0.577      0.674      0.652      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50       1.7G       1.02      1.207      1.159        114        512: 100% 158/158 [00:15<00:00, 10.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.40it/s]
#                    all        630       5077      0.551      0.677      0.657       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50       1.7G      1.032       1.24      1.172         56        512: 100% 158/158 [00:15<00:00, 10.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.50it/s]
#                    all        630       5077      0.577      0.658      0.653       0.46
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50       1.7G      1.014      1.197      1.156         96        512: 100% 158/158 [00:15<00:00, 10.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.64it/s]
#                    all        630       5077      0.602      0.668       0.67      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.91G      1.014      1.202      1.166        106        512: 100% 158/158 [00:15<00:00, 10.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.36it/s]
#                    all        630       5077      0.612      0.669      0.674       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.68G      1.011      1.195       1.15         55        512: 100% 158/158 [00:15<00:00, 10.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.59it/s]
#                    all        630       5077      0.623      0.659      0.673       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.57G      1.006      1.208      1.165         69        512: 100% 158/158 [00:15<00:00, 10.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:02<00:00,  6.80it/s]
#                    all        630       5077      0.597      0.677      0.666      0.476
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.56G     0.9943      1.152      1.131         51        512: 100% 158/158 [00:17<00:00,  8.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.43it/s]
#                    all        630       5077      0.602      0.665      0.665      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.69G      0.982      1.132      1.122         50        512: 100% 158/158 [00:14<00:00, 10.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.30it/s]
#                    all        630       5077      0.642      0.662       0.69      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.68G     0.9702      1.118       1.12         33        512: 100% 158/158 [00:15<00:00, 10.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630       5077      0.613      0.673      0.684      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.69G     0.9594      1.096      1.113         43        512: 100% 158/158 [00:15<00:00, 10.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.23it/s]
#                    all        630       5077      0.647      0.659      0.692      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.68G     0.9578      1.096       1.11         48        512: 100% 158/158 [00:14<00:00, 10.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.21it/s]
#                    all        630       5077      0.627      0.676       0.69      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.69G     0.9434      1.086      1.102         58        512: 100% 158/158 [00:15<00:00, 10.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630       5077      0.612      0.696      0.694      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.56G     0.9363      1.073      1.101         57        512: 100% 158/158 [00:15<00:00, 10.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.33it/s]
#                    all        630       5077      0.615      0.692      0.694      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.57G      0.933      1.066      1.098         28        512: 100% 158/158 [00:15<00:00, 10.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.56it/s]
#                    all        630       5077      0.626      0.687      0.694      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.56G     0.9304      1.053      1.098         52        512: 100% 158/158 [00:15<00:00, 10.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:02<00:00,  6.71it/s]
#                    all        630       5077      0.634      0.679      0.698      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      1.57G     0.9217       1.05      1.092         77        512: 100% 158/158 [00:15<00:00, 10.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:02<00:00,  6.84it/s]
#                    all        630       5077      0.644       0.68      0.702       0.51
#
# 50 epochs completed in 0.278 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.69it/s]
#                    all        630       5077      0.645      0.681      0.702       0.51
#                    C.R        630       2213      0.645      0.796      0.798      0.582
#                    C.V        630       2056      0.604      0.367      0.469      0.261
#                    S.P        630        808      0.685      0.879       0.84      0.689
# Speed: 0.1ms preprocess, 3.9ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 16.4 s, sys: 2.03 s, total: 18.4 s
# Wall time: 21min 58s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/data.yaml
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_3/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:11<00:00,  3.60it/s]
#                    all        630       5077      0.646      0.681      0.702      0.511
#                    C.R        630       2213      0.645      0.795      0.798      0.583
#                    C.V        630       2056      0.605      0.367      0.469      0.261
#                    S.P        630        808      0.686       0.88       0.84      0.689
# Speed: 0.3ms preprocess, 1.3ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
