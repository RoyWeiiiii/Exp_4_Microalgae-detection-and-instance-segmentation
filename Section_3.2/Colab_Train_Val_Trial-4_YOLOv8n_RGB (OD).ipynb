# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_4/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_4/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_4/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4
#   version: 4
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4/dataset/4

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_4/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 177MB/s]
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_4/data.yaml
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_Trial_4/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:12<00:00,  3.23it/s]
#                    all        630       5064      0.706      0.777      0.794      0.575
#                    C.R        630       3116      0.769      0.917      0.916      0.688
#                    C.V        630       1140      0.659      0.554      0.621      0.337
#                    S.P        630        808      0.691      0.859      0.844        0.7
# Speed: 0.4ms preprocess, 1.4ms inference, 0.0ms loss, 4.9ms postprocess per image
# Results saved to runs/detect/val
# ...

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
