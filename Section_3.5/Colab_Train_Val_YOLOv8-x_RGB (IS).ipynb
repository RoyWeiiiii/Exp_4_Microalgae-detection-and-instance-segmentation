# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2-instance-seg
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2-instance-seg/dataset/1

# %%
# train yolov8m on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=segment mode=train model=yolov8x-seg.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x-seg.pt to 'yolov8x-seg.pt'...
# 100% 137M/137M [00:01<00:00, 102MB/s]
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=segment, mode=train, model=yolov8x-seg.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/segment/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 4.55MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1  12319097  ultralytics.nn.modules.head.Segment          [3, 32, 320, [320, 640, 640]]
# YOLOv8x-seg summary: 401 layers, 71753737 parameters, 71753721 gradients, 344.5 GFLOPs
#
# Transferred 651/657 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/segment/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 6.94MB/s]
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train/labels.cache... 2516 images, 4 backgrounds, 0 corrupt: 100% 2520/2520 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train/images/Spirulina0038_jpg.rf.1bd187bca96a410bc5e9529e0e598be5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train/images/Spirulina0203_jpg.rf.43ba6357c039e246bb0dd618e65c4a0d.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
# Plotting labels to runs/segment/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 106 weight(decay=0.0), 117 weight(decay=0.0005), 116 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/segment/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      10.8G     0.9696      1.525      1.147     0.9215        175        512: 100% 158/158 [02:22<00:00,  1.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:23<00:00,  1.19s/it]
#                    all        630      10552      0.546      0.637      0.564       0.36      0.492      0.572      0.476      0.199
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      10.2G     0.9848      1.419     0.8519     0.9255        216        512: 100% 158/158 [01:30<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.28it/s]
#                    all        630      10552      0.714      0.753      0.745      0.518      0.677      0.715      0.686      0.335
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      10.2G     0.9371      1.357     0.7999      0.907        243        512: 100% 158/158 [01:29<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.31it/s]
#                    all        630      10552      0.733      0.796      0.806      0.595      0.717      0.722       0.74       0.37
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      10.3G     0.9312      1.332     0.7774     0.9043         95        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.37it/s]
#                    all        630      10552      0.763      0.828      0.846      0.642      0.754      0.814      0.811      0.417
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      10.2G     0.8897      1.306     0.7297     0.8931        155        512: 100% 158/158 [01:27<00:00,  1.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:09<00:00,  2.22it/s]
#                    all        630      10552      0.773      0.809      0.835      0.644      0.759       0.79        0.8      0.431
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      10.2G     0.8717      1.261     0.6963     0.8826        136        512: 100% 158/158 [01:29<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.35it/s]
#                    all        630      10552      0.803      0.853      0.882      0.684       0.77      0.807       0.81      0.409
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      10.2G     0.8516      1.269     0.6876      0.883        131        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.29it/s]
#                    all        630      10552      0.826      0.848      0.891      0.695      0.805        0.8      0.831      0.451
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      10.2G     0.8339      1.246     0.6642     0.8801         68        512: 100% 158/158 [01:27<00:00,  1.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.43it/s]
#                    all        630      10552       0.81      0.856      0.891      0.703      0.778      0.806      0.831      0.445
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      10.2G     0.8167      1.226     0.6579     0.8779        149        512: 100% 158/158 [01:29<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.35it/s]
#                    all        630      10552      0.826      0.886      0.902      0.724      0.805      0.824      0.838       0.43
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      10.3G     0.8129      1.228     0.6454     0.8792        242        512: 100% 158/158 [01:26<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.36it/s]
#                    all        630      10552      0.816      0.839      0.886      0.706      0.794      0.788      0.833      0.434
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      10.3G     0.8029       1.22     0.6339       0.87        167        512: 100% 158/158 [01:29<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.26it/s]
#                    all        630      10552      0.838      0.871      0.911      0.728      0.821      0.824      0.859      0.481
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      10.2G     0.7807      1.185     0.6057     0.8638        144        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.35it/s]
#                    all        630      10552      0.862      0.884      0.925      0.758      0.828      0.841      0.871      0.471
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      10.3G     0.7676      1.167     0.5936     0.8623        124        512: 100% 158/158 [01:28<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.36it/s]
#                    all        630      10552      0.873      0.881       0.93      0.755      0.833      0.849      0.874      0.472
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      10.3G     0.7629      1.149     0.5842     0.8589        165        512: 100% 158/158 [01:30<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.28it/s]
#                    all        630      10552      0.846      0.881      0.918      0.746      0.813      0.848      0.869      0.478
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      10.2G     0.7667      1.167     0.5781     0.8559        327        512: 100% 158/158 [01:28<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.41it/s]
#                    all        630      10552       0.87      0.865       0.92      0.751      0.839      0.826      0.864      0.471
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      10.2G     0.7565      1.152     0.5692     0.8607        164        512: 100% 158/158 [01:26<00:00,  1.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.35it/s]
#                    all        630      10552      0.843      0.896       0.92      0.753      0.823      0.842      0.861       0.46
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      10.1G     0.7465      1.152     0.5691     0.8608        183        512: 100% 158/158 [01:30<00:00,  1.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.34it/s]
#                    all        630      10552      0.845      0.891      0.927      0.754       0.81      0.852      0.863      0.452
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      10.3G     0.7371      1.135      0.566     0.8527        118        512: 100% 158/158 [01:29<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.33it/s]
#                    all        630      10552      0.864      0.845      0.924      0.758      0.808      0.818      0.862      0.464
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      10.2G     0.7272      1.123     0.5576     0.8526        199        512: 100% 158/158 [01:30<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.36it/s]
#                    all        630      10552      0.866      0.882      0.924      0.756      0.832      0.828      0.867       0.47
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      10.2G      0.726      1.125     0.5494       0.85        505        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.45it/s]
#                    all        630      10552      0.866      0.893      0.934      0.776      0.843      0.858      0.885      0.488
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      10.2G     0.7282      1.138     0.5381      0.852        155        512: 100% 158/158 [01:27<00:00,  1.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.27it/s]
#                    all        630      10552      0.851      0.891       0.92      0.753      0.842       0.85       0.88       0.48
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      10.2G     0.7197      1.119     0.5398     0.8535        120        512: 100% 158/158 [01:29<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.42it/s]
#                    all        630      10552       0.87      0.916      0.936       0.78      0.841      0.873      0.885      0.495
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      10.1G     0.7055      1.091      0.528     0.8471        131        512: 100% 158/158 [01:28<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.36it/s]
#                    all        630      10552      0.876      0.895      0.939      0.793      0.846      0.863      0.885       0.49
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      10.2G     0.7016      1.101     0.5262     0.8477        217        512: 100% 158/158 [01:27<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.26it/s]
#                    all        630      10552      0.869      0.904      0.938      0.784      0.836       0.87      0.886      0.486
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      10.2G     0.6974      1.069     0.5192      0.844        104        512: 100% 158/158 [01:29<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.38it/s]
#                    all        630      10552      0.869      0.898      0.938      0.784      0.839      0.861      0.883      0.496
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      10.2G      0.689      1.084      0.508     0.8435         99        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.35it/s]
#                    all        630      10552      0.878      0.894       0.94      0.786      0.838       0.87      0.886      0.488
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      10.1G     0.6938      1.093      0.511     0.8449        182        512: 100% 158/158 [01:29<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.41it/s]
#                    all        630      10552      0.875      0.909      0.942      0.799      0.843      0.875      0.892        0.5
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      10.2G     0.6872      1.079     0.5045     0.8439        119        512: 100% 158/158 [01:27<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.29it/s]
#                    all        630      10552      0.878      0.908      0.946      0.804      0.841      0.881      0.903      0.527
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      10.2G     0.6788      1.063     0.4914     0.8398        118        512: 100% 158/158 [01:29<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.28it/s]
#                    all        630      10552      0.884      0.908      0.947      0.793      0.864      0.873      0.901      0.521
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      10.3G     0.6769      1.075     0.4957     0.8403         98        512: 100% 158/158 [01:30<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.31it/s]
#                    all        630      10552      0.875      0.926      0.951      0.809      0.847       0.89      0.902      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      10.2G     0.6701      1.069     0.4843     0.8373        166        512: 100% 158/158 [01:29<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.40it/s]
#                    all        630      10552      0.859      0.916      0.939      0.797       0.83      0.878      0.886      0.502
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      10.3G     0.6714      1.066     0.4906     0.8396        305        512: 100% 158/158 [01:28<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.25it/s]
#                    all        630      10552       0.89      0.903      0.945      0.804      0.856      0.862      0.894      0.511
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      10.2G     0.6633      1.036     0.4817     0.8393        145        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.25it/s]
#                    all        630      10552      0.884      0.907      0.945      0.806      0.869      0.876      0.911      0.532
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      10.4G     0.6527      1.041     0.4727     0.8403        202        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.34it/s]
#                    all        630      10552      0.882      0.912      0.949      0.806      0.853      0.875      0.905      0.523
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      10.2G      0.657      1.042     0.4723     0.8363        180        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.34it/s]
#                    all        630      10552      0.881       0.91      0.948      0.812      0.856      0.879      0.908      0.528
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      10.2G     0.6461      1.019     0.4674     0.8358        200        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.30it/s]
#                    all        630      10552      0.874      0.908      0.948      0.807      0.844      0.869        0.9      0.519
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      10.3G     0.6426      1.014     0.4638     0.8314        108        512: 100% 158/158 [01:30<00:00,  1.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.37it/s]
#                    all        630      10552      0.891      0.909      0.948      0.816      0.853      0.873      0.897      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      10.2G     0.6441      1.029     0.4603      0.835        111        512: 100% 158/158 [01:28<00:00,  1.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.24it/s]
#                    all        630      10552      0.884      0.913       0.95      0.818      0.861      0.871      0.904      0.519
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      10.2G      0.646      1.025     0.4576     0.8339         48        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.41it/s]
#                    all        630      10552      0.892       0.91      0.953      0.816      0.864      0.879      0.909      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      10.2G     0.6353      1.007     0.4557     0.8327        175        512: 100% 158/158 [01:28<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.24it/s]
#                    all        630      10552       0.88      0.918      0.954      0.818      0.852       0.89      0.911      0.529
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      10.2G     0.6457      1.032     0.4343     0.8233        106        512: 100% 158/158 [01:08<00:00,  2.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.44it/s]
#                    all        630      10552      0.904      0.906      0.952       0.82      0.863      0.871      0.904      0.527
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      10.2G     0.6419      1.021     0.4337      0.822        178        512: 100% 158/158 [01:01<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.42it/s]
#                    all        630      10552      0.896      0.914       0.95      0.814      0.866      0.877      0.906      0.526
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      10.1G     0.6398      1.038     0.4213     0.8223         45        512: 100% 158/158 [01:01<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.45it/s]
#                    all        630      10552      0.892      0.924       0.95      0.822      0.855      0.883      0.902      0.532
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      10.2G     0.6321      1.012     0.4143     0.8207         79        512: 100% 158/158 [01:02<00:00,  2.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.43it/s]
#                    all        630      10552      0.907        0.9      0.953      0.819      0.876      0.869      0.911      0.533
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      10.1G     0.6269      1.007      0.409     0.8177        195        512: 100% 158/158 [01:01<00:00,  2.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.51it/s]
#                    all        630      10552      0.909      0.901      0.955      0.824      0.878      0.866      0.913       0.53
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      10.2G       0.62     0.9981     0.4066      0.817         81        512: 100% 158/158 [01:01<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.40it/s]
#                    all        630      10552      0.904      0.921      0.957       0.83      0.861      0.896      0.912      0.535
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      10.3G      0.618     0.9866     0.3942     0.8166        211        512: 100% 158/158 [01:01<00:00,  2.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.42it/s]
#                    all        630      10552      0.905      0.923      0.958      0.833       0.88      0.897      0.927       0.56
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      10.2G     0.6085     0.9874     0.3897      0.813        109        512: 100% 158/158 [01:02<00:00,  2.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.47it/s]
#                    all        630      10552      0.891      0.931      0.958      0.834      0.875       0.89      0.923       0.55
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      10.2G     0.6016     0.9617      0.383     0.8121        130        512: 100% 158/158 [01:01<00:00,  2.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.42it/s]
#                    all        630      10552      0.904       0.92      0.959      0.833       0.88      0.887      0.921      0.546
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      10.1G     0.5969      0.964     0.3811     0.8114        153        512: 100% 158/158 [01:01<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:08<00:00,  2.44it/s]
#                    all        630      10552      0.905      0.918       0.96      0.838      0.875      0.892      0.925      0.552
#
# 50 epochs completed in 1.330 hours.
# Optimizer stripped from runs/segment/train/weights/last.pt, 143.9MB
# Optimizer stripped from runs/segment/train/weights/best.pt, 143.9MB
#
# Validating runs/segment/train/weights/best.pt...
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71723545 parameters, 0 gradients, 343.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:13<00:00,  1.44it/s]
#                    all        630      10552      0.907      0.921      0.958      0.833      0.883      0.896      0.927       0.56
#                    C.R        630       3346      0.898      0.881      0.951      0.825      0.908      0.889      0.957      0.628
#                    C.V        630       6442      0.965      0.971       0.99      0.808      0.912      0.917       0.93      0.455
#                    S.P        630        764      0.858      0.912      0.934      0.866      0.828      0.881      0.894      0.596
# Speed: 0.1ms preprocess, 6.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/segment/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 39.7 s, sys: 4.36 s, total: 44 s
# Wall time: 1h 21min 14s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task= segment mode= val model= /content/runs/segment/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27224121 parameters, 0 gradients, 110.0 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 40/40 [00:21<00:00,  1.87it/s]
#                    all        630      10552      0.897      0.923      0.957      0.832      0.861      0.889      0.912      0.537
#                    C.R        630       3346      0.883      0.884       0.95      0.819      0.889      0.894      0.953      0.592
#                    C.V        630       6442      0.969       0.97       0.99      0.809      0.885      0.887      0.892      0.397
#                    S.P        630        764      0.838      0.916      0.932      0.867      0.808      0.886      0.891      0.621
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
