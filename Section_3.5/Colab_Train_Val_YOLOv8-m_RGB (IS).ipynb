# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2-instance-seg
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2-instance-seg/dataset/1

# %%
# train yolov8m on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=segment mode=train model=yolov8m-seg.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8m-seg.pt to 'yolov8m-seg.pt'...
# 100% 52.4M/52.4M [00:00<00:00, 220MB/s]
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=segment, mode=train, model=yolov8m-seg.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/segment/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 17.5MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   5160761  ultralytics.nn.modules.head.Segment          [3, 32, 192, [192, 384, 576]]
# YOLOv8m-seg summary: 331 layers, 27241385 parameters, 27241369 gradients, 110.4 GFLOPs
#
# Transferred 531/537 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/segment/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 81.6MB/s]
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train/labels.cache... 2516 images, 4 backgrounds, 0 corrupt: 100% 2520/2520 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train/images/Spirulina0038_jpg.rf.1bd187bca96a410bc5e9529e0e598be5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train/images/Spirulina0203_jpg.rf.43ba6357c039e246bb0dd618e65c4a0d.jpg: 1 duplicate labels removed
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
# Plotting labels to runs/segment/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 86 weight(decay=0.0), 97 weight(decay=0.0005), 96 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/segment/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.96G     0.9648      1.526       1.19     0.9053        175        512: 100% 158/158 [01:36<00:00,  1.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:11<00:00,  1.78it/s]
#                    all        630      10552      0.755      0.785      0.812      0.581      0.709      0.749      0.738      0.368
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      5.65G     0.9653        1.4     0.8389     0.9084        216        512: 100% 158/158 [01:21<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.91it/s]
#                    all        630      10552      0.711      0.811      0.769      0.547      0.678      0.756      0.707      0.325
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.76G     0.9341      1.337     0.7815     0.8955        243        512: 100% 158/158 [01:23<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.97it/s]
#                    all        630      10552       0.71      0.767      0.777      0.573      0.686      0.734      0.726      0.371
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.91G      0.926      1.312     0.7692     0.8921         95        512: 100% 158/158 [01:21<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.78it/s]
#                    all        630      10552      0.787      0.841      0.864      0.649      0.755       0.79      0.789      0.397
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.19G     0.8762      1.276     0.7055     0.8813        155        512: 100% 158/158 [01:21<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.60it/s]
#                    all        630      10552      0.818      0.847      0.877      0.682        0.8      0.804      0.825      0.441
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.67G     0.8675      1.246     0.6872     0.8741        136        512: 100% 158/158 [01:21<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.74it/s]
#                    all        630      10552      0.824      0.843      0.882      0.677      0.794      0.805       0.83      0.436
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.68G     0.8548      1.247     0.6855     0.8756        131        512: 100% 158/158 [01:22<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.66it/s]
#                    all        630      10552      0.836      0.853      0.897        0.7      0.822      0.817      0.853      0.461
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.87G     0.8335      1.234     0.6567     0.8713         68        512: 100% 158/158 [01:21<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.75it/s]
#                    all        630      10552      0.799      0.841      0.879      0.701      0.792      0.798      0.835       0.45
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.67G     0.8201      1.211     0.6371     0.8684        149        512: 100% 158/158 [01:20<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.82it/s]
#                    all        630      10552      0.837      0.873      0.906      0.724      0.808      0.834      0.851      0.458
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/50       5.7G     0.8062      1.201     0.6276     0.8714        242        512: 100% 158/158 [01:20<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.64it/s]
#                    all        630      10552      0.842      0.882      0.914      0.736      0.814      0.837      0.858      0.463
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.61G     0.8039      1.191     0.6184     0.8659        167        512: 100% 158/158 [01:24<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.79it/s]
#                    all        630      10552       0.85      0.885      0.919      0.749      0.837      0.831      0.864       0.47
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      6.66G     0.7871      1.168     0.6006     0.8579        144        512: 100% 158/158 [01:22<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.75it/s]
#                    all        630      10552      0.862      0.895      0.935      0.772      0.835      0.851      0.885      0.492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.87G     0.7736      1.161     0.5957     0.8573        124        512: 100% 158/158 [01:23<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.72it/s]
#                    all        630      10552      0.844      0.881      0.917       0.74      0.802      0.838      0.848       0.44
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.52G     0.7711      1.146     0.6024     0.8537        165        512: 100% 158/158 [01:22<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.51it/s]
#                    all        630      10552      0.855      0.882      0.921      0.744      0.827      0.845      0.865      0.476
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.63G     0.7684      1.157     0.5707     0.8522        327        512: 100% 158/158 [01:23<00:00,  1.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.79it/s]
#                    all        630      10552      0.805      0.798      0.903      0.723      0.788      0.759      0.857      0.482
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      5.86G     0.7554      1.139     0.5676     0.8541        164        512: 100% 158/158 [01:20<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.85it/s]
#                    all        630      10552      0.851      0.899      0.931      0.762      0.837      0.838      0.874       0.49
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/50       5.6G     0.7531      1.142     0.5709     0.8555        183        512: 100% 158/158 [01:19<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.74it/s]
#                    all        630      10552      0.864       0.89      0.929      0.747      0.831      0.835      0.857      0.451
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       6.1G     0.7492      1.132     0.5635      0.849        118        512: 100% 158/158 [01:22<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.73it/s]
#                    all        630      10552      0.859      0.878      0.926      0.762      0.823      0.838      0.868      0.474
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/50       6.1G       0.74      1.116     0.5584     0.8474        199        512: 100% 158/158 [01:22<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.99it/s]
#                    all        630      10552      0.861      0.899      0.934      0.772      0.824      0.859      0.879      0.478
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      5.87G     0.7293      1.114     0.5465     0.8452        505        512: 100% 158/158 [01:19<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.04it/s]
#                    all        630      10552      0.867       0.89      0.931      0.773      0.834      0.849      0.871      0.472
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/50       5.7G     0.7313      1.129     0.5363      0.846        155        512: 100% 158/158 [01:19<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.82it/s]
#                    all        630      10552      0.875      0.897       0.94      0.779      0.845      0.865      0.887      0.492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      5.66G     0.7218      1.109     0.5387     0.8471        120        512: 100% 158/158 [01:18<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.90it/s]
#                    all        630      10552       0.89      0.906      0.943      0.787      0.861      0.877      0.901      0.511
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      5.88G     0.7137      1.087     0.5215     0.8408        131        512: 100% 158/158 [01:19<00:00,  1.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.62it/s]
#                    all        630      10552      0.866      0.908      0.932       0.78      0.849       0.87      0.887      0.507
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/50       5.9G     0.7134      1.094     0.5212     0.8436        217        512: 100% 158/158 [01:17<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.95it/s]
#                    all        630      10552      0.881      0.904      0.941      0.792      0.848      0.872      0.895      0.505
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      5.92G     0.7069      1.069     0.5229     0.8393        104        512: 100% 158/158 [01:20<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.99it/s]
#                    all        630      10552      0.883      0.903      0.945      0.789       0.85       0.87      0.891      0.501
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      5.64G     0.7023      1.079     0.5261     0.8395         99        512: 100% 158/158 [01:19<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.99it/s]
#                    all        630      10552      0.886      0.903      0.947      0.791      0.848      0.862      0.891      0.495
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      5.79G     0.7012      1.089     0.5171     0.8403        182        512: 100% 158/158 [01:20<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.87it/s]
#                    all        630      10552       0.87      0.921      0.944        0.8      0.858      0.873      0.902      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      5.79G     0.6982      1.081     0.5044     0.8397        119        512: 100% 158/158 [01:23<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.82it/s]
#                    all        630      10552      0.898      0.895      0.946      0.799       0.86      0.853      0.892      0.512
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      5.59G     0.6898       1.06     0.4968     0.8379        118        512: 100% 158/158 [01:20<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.91it/s]
#                    all        630      10552      0.893      0.907       0.95      0.803      0.859      0.868        0.9      0.511
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      5.74G     0.6943       1.08     0.5055     0.8371         98        512: 100% 158/158 [01:20<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.75it/s]
#                    all        630      10552      0.871      0.917      0.945      0.798      0.843      0.878      0.896      0.512
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      5.64G     0.6762       1.06     0.4863     0.8353        166        512: 100% 158/158 [01:22<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.88it/s]
#                    all        630      10552      0.892        0.9      0.947      0.798      0.861      0.855      0.895      0.504
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      5.73G     0.6816      1.068     0.4915     0.8359        305        512: 100% 158/158 [01:19<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.78it/s]
#                    all        630      10552      0.883      0.917      0.947      0.809      0.856      0.865      0.896      0.511
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.61G     0.6715      1.035     0.4842     0.8365        145        512: 100% 158/158 [01:20<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.66it/s]
#                    all        630      10552      0.884      0.907      0.947      0.807      0.858      0.871      0.906      0.525
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      6.19G     0.6648       1.04     0.4837     0.8365        202        512: 100% 158/158 [01:20<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.76it/s]
#                    all        630      10552      0.894      0.883      0.948      0.803      0.872      0.849      0.906      0.523
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.92G     0.6668       1.04     0.4776     0.8336        180        512: 100% 158/158 [01:24<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.84it/s]
#                    all        630      10552       0.89      0.915      0.948      0.814      0.861       0.88      0.907      0.527
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.59G     0.6588      1.023     0.4724     0.8355        200        512: 100% 158/158 [01:20<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.90it/s]
#                    all        630      10552      0.902      0.903       0.95      0.813      0.872      0.873      0.909      0.535
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.75G     0.6562      1.018     0.4702     0.8303        108        512: 100% 158/158 [01:22<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.92it/s]
#                    all        630      10552      0.891      0.919      0.951      0.814      0.856      0.884      0.905      0.526
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.62G     0.6523      1.029     0.4654     0.8307        111        512: 100% 158/158 [01:20<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.80it/s]
#                    all        630      10552       0.89      0.908      0.953      0.819      0.863      0.878      0.916      0.538
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.68G     0.6546      1.027     0.4647     0.8305         48        512: 100% 158/158 [01:24<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.77it/s]
#                    all        630      10552       0.89      0.908      0.951      0.809      0.865      0.869      0.907       0.52
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.01G     0.6395      1.006     0.4604     0.8301        175        512: 100% 158/158 [01:21<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.69it/s]
#                    all        630      10552      0.892      0.913      0.954      0.821      0.863      0.876      0.913      0.534
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.38G     0.6555      1.033     0.4367     0.8232        106        512: 100% 158/158 [00:53<00:00,  2.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.78it/s]
#                    all        630      10552      0.913      0.906      0.953      0.823      0.881      0.873      0.911      0.538
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       5.4G     0.6484      1.021     0.4361      0.821        178        512: 100% 158/158 [00:47<00:00,  3.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.98it/s]
#                    all        630      10552      0.894      0.917       0.95      0.813      0.863      0.886      0.907      0.533
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.32G     0.6442      1.035     0.4281     0.8213         45        512: 100% 158/158 [00:46<00:00,  3.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.11it/s]
#                    all        630      10552      0.895      0.921      0.955      0.823      0.866       0.89      0.917      0.544
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.59G     0.6345      1.003     0.4213     0.8185         79        512: 100% 158/158 [00:48<00:00,  3.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.00it/s]
#                    all        630      10552      0.904      0.913      0.954       0.82       0.87      0.878      0.911      0.526
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.31G     0.6327      1.007     0.4168     0.8156        195        512: 100% 158/158 [00:46<00:00,  3.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.93it/s]
#                    all        630      10552      0.894      0.914      0.953      0.821      0.856      0.885       0.91      0.533
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.42G     0.6289     0.9999     0.4152     0.8177         81        512: 100% 158/158 [00:47<00:00,  3.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.13it/s]
#                    all        630      10552      0.901      0.919      0.956      0.827       0.87      0.888      0.915      0.543
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       47/50       5.5G     0.6237     0.9833     0.4042     0.8155        211        512: 100% 158/158 [00:48<00:00,  3.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.99it/s]
#                    all        630      10552      0.902      0.915      0.955      0.832      0.873      0.886      0.918      0.553
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.64G     0.6158     0.9844     0.3982     0.8115        109        512: 100% 158/158 [00:46<00:00,  3.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.89it/s]
#                    all        630      10552      0.895      0.925      0.955      0.829      0.867      0.898      0.919      0.551
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.67G     0.6079     0.9592     0.3946     0.8117        130        512: 100% 158/158 [00:45<00:00,  3.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.08it/s]
#                    all        630      10552      0.897      0.923      0.957      0.831      0.866      0.895       0.92      0.554
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.58G     0.6067     0.9655     0.3898     0.8119        153        512: 100% 158/158 [00:47<00:00,  3.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.03it/s]
#                    all        630      10552      0.895      0.927      0.957      0.832      0.864      0.897      0.919      0.552
#
# 50 epochs completed in 1.161 hours.
# Optimizer stripped from runs/segment/train/weights/last.pt, 54.8MB
# Optimizer stripped from runs/segment/train/weights/best.pt, 54.8MB
#
# Validating runs/segment/train/weights/best.pt...
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27224121 parameters, 0 gradients, 110.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:13<00:00,  1.51it/s]
#                    all        630      10552      0.897      0.923      0.957      0.831      0.866      0.895      0.919      0.554
#                    C.R        630       3346      0.883      0.884       0.95      0.817       0.89      0.896      0.954      0.607
#                    C.V        630       6442      0.969       0.97       0.99      0.808      0.901      0.903      0.913      0.431
#                    S.P        630        764      0.838      0.916      0.932      0.867      0.807      0.886      0.891      0.625
# Speed: 0.1ms preprocess, 2.5ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/segment/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 38.3 s, sys: 4.52 s, total: 42.8 s
# Wall time: 1h 11min 48s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task= segment mode= val model= /content/runs/segment/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27224121 parameters, 0 gradients, 110.0 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 40/40 [00:21<00:00,  1.87it/s]
#                    all        630      10552      0.897      0.923      0.957      0.832      0.861      0.889      0.912      0.537
#                    C.R        630       3346      0.883      0.884       0.95      0.819      0.889      0.894      0.953      0.592
#                    C.V        630       6442      0.969       0.97       0.99      0.809      0.885      0.887      0.892      0.397
#                    S.P        630        764      0.838      0.916      0.932      0.867      0.808      0.886      0.891      0.621
# Speed: 0.6ms preprocess, 7.6ms inference, 0.0ms loss, 5.0ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
