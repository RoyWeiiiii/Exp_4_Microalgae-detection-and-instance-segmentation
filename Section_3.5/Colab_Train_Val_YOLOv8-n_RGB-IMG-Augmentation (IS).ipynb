# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2-instance-seg
#   version: 3
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2-instance-seg/dataset/3

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=segment mode=train model=yolov8n-seg.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n-seg.pt to 'yolov8n-seg.pt'...
# 100% 6.73M/6.73M [00:00<00:00, 78.6MB/s]
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=segment, mode=train, model=yolov8n-seg.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/segment/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 14.3MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1   1004665  ultralytics.nn.modules.head.Segment          [3, 32, 64, [64, 128, 256]]
# YOLOv8n-seg summary: 261 layers, 3264201 parameters, 3264185 gradients, 12.1 GFLOPs
#
# Transferred 381/417 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/segment/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 73.1MB/s]
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/train/labels... 7560 images, 0 backgrounds, 0 corrupt: 100% 7560/7560 [08:49<00:00, 14.29it/s]
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/train/images/Spirulina0038_jpg.rf.1bd187bca96a410bc5e9529e0e598be5.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/train/images/Spirulina0038_jpg.rf.4fe060b899732c4bfac0184254893ad0.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/train/images/Spirulina0203_jpg.rf.43ba6357c039e246bb0dd618e65c4a0d.jpg: 1 duplicate labels removed
# train: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/valid/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:29<00:00, 21.25it/s]
# val: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/valid/labels.cache
# Plotting labels to runs/segment/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 66 weight(decay=0.0), 77 weight(decay=0.0005), 76 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/segment/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      3.27G      1.677      2.687      1.724      1.049        151        512: 100% 473/473 [03:52<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.13it/s]
#                    all        630      10552      0.699      0.692      0.767      0.538      0.662      0.625      0.683      0.344
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.75G      1.559      2.443      1.256      1.014        136        512: 100% 473/473 [03:40<00:00,  2.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.87it/s]
#                    all        630      10552      0.771       0.79      0.847      0.605       0.76      0.761        0.8      0.408
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.68G      1.503      2.314      1.167      1.007        162        512: 100% 473/473 [03:32<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.98it/s]
#                    all        630      10552      0.752      0.827      0.853       0.61      0.733      0.785      0.793      0.409
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.92G      1.487      2.299      1.129     0.9957        105        512: 100% 473/473 [03:36<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.22it/s]
#                    all        630      10552       0.78      0.813      0.863      0.636      0.756      0.761      0.794      0.397
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      3.44G      1.416      2.191      1.059     0.9831         67        512: 100% 473/473 [03:33<00:00,  2.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.15it/s]
#                    all        630      10552      0.689       0.67      0.807      0.602      0.663      0.632      0.752      0.381
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       3.7G      1.409      2.184      1.025     0.9742        128        512: 100% 473/473 [03:38<00:00,  2.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.02it/s]
#                    all        630      10552      0.779        0.8      0.861       0.66      0.776      0.769      0.829      0.457
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      3.61G      1.372      2.138     0.9992     0.9675        137        512: 100% 473/473 [03:38<00:00,  2.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.21it/s]
#                    all        630      10552      0.813      0.849      0.886      0.679       0.79      0.802      0.832       0.43
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.49G      1.344      2.108     0.9728     0.9612        171        512: 100% 473/473 [03:37<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.14it/s]
#                    all        630      10552      0.822      0.846        0.9        0.7       0.81      0.818      0.856       0.46
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/50       2.6G      1.336      2.083     0.9718     0.9612        156        512: 100% 473/473 [03:36<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.18it/s]
#                    all        630      10552      0.812      0.838      0.895      0.703      0.801      0.786      0.839      0.447
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.03G      1.324      2.065     0.9446      0.952        136        512: 100% 473/473 [03:37<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.06it/s]
#                    all        630      10552       0.84      0.867       0.91       0.72      0.811      0.824      0.851       0.44
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.89G      1.291      2.012     0.9118     0.9452        142        512: 100% 473/473 [03:38<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.30it/s]
#                    all        630      10552      0.841      0.853      0.902       0.72      0.815      0.819      0.851      0.471
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.43G      1.264      1.984     0.8968      0.943        151        512: 100% 473/473 [03:39<00:00,  2.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.06it/s]
#                    all        630      10552      0.846      0.869      0.915      0.724      0.817      0.834       0.86      0.457
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.87G       1.27      1.977     0.8896      0.943        100        512: 100% 473/473 [03:37<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.04it/s]
#                    all        630      10552      0.848       0.88      0.918      0.744      0.828      0.863      0.878      0.484
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/50       2.5G      1.256      1.958     0.8875     0.9387        211        512: 100% 473/473 [03:35<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.87it/s]
#                    all        630      10552      0.831      0.873      0.913      0.722      0.801      0.833      0.851      0.446
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.94G      1.233      1.946     0.8715     0.9338        138        512: 100% 473/473 [03:37<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.11it/s]
#                    all        630      10552      0.826      0.876      0.903      0.721       0.81      0.836      0.851      0.447
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      3.12G      1.232      1.925     0.8655     0.9328        187        512: 100% 473/473 [03:39<00:00,  2.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.28it/s]
#                    all        630      10552      0.849      0.859      0.914      0.737      0.826      0.831      0.864      0.474
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      3.13G      1.222      1.913     0.8501     0.9329        168        512: 100% 473/473 [03:35<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.83it/s]
#                    all        630      10552      0.845      0.877      0.919      0.735      0.817      0.841      0.867      0.464
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.96G      1.216      1.906     0.8423     0.9284        130        512: 100% 473/473 [03:34<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.95it/s]
#                    all        630      10552       0.83      0.848      0.911      0.737      0.799      0.817      0.846      0.452
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.82G      1.209      1.897     0.8404      0.926        138        512: 100% 473/473 [03:36<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.31it/s]
#                    all        630      10552      0.854      0.873      0.923      0.756       0.84      0.844      0.876      0.485
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.51G      1.195      1.869     0.8307     0.9255        155        512: 100% 473/473 [03:32<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.08it/s]
#                    all        630      10552      0.859      0.869       0.92      0.751       0.84       0.84      0.871      0.479
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      3.34G      1.168      1.839      0.812     0.9215        124        512: 100% 473/473 [03:38<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.10it/s]
#                    all        630      10552      0.839      0.865      0.916      0.741       0.82      0.824      0.866      0.466
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.75G      1.169      1.836     0.8036     0.9181        127        512: 100% 473/473 [03:37<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.83it/s]
#                    all        630      10552      0.716      0.717      0.832      0.652      0.705      0.676      0.788      0.436
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/50       2.6G      1.174      1.853      0.814     0.9206         70        512: 100% 473/473 [03:38<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.04it/s]
#                    all        630      10552      0.864      0.885      0.934      0.767      0.834      0.852      0.884      0.492
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/50       3.5G      1.159      1.835     0.7967     0.9165         99        512: 100% 473/473 [03:37<00:00,  2.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.15it/s]
#                    all        630      10552      0.869      0.882      0.934       0.77       0.85      0.863      0.891      0.497
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.68G      1.162      1.831     0.7933     0.9181        169        512: 100% 473/473 [03:34<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.30it/s]
#                    all        630      10552      0.863      0.894      0.932      0.768      0.832      0.865      0.885      0.494
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.92G      1.138      1.806     0.7753     0.9106        120        512: 100% 473/473 [03:36<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.25it/s]
#                    all        630      10552      0.883      0.882      0.937      0.771      0.857      0.858      0.892      0.493
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.79G      1.138      1.788     0.7667     0.9088         83        512: 100% 473/473 [03:34<00:00,  2.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.31it/s]
#                    all        630      10552      0.869      0.888      0.936      0.773      0.848      0.865      0.893      0.506
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.77G      1.125      1.776     0.7686     0.9096        214        512: 100% 473/473 [03:35<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.14it/s]
#                    all        630      10552      0.872      0.882      0.933      0.768      0.852      0.852      0.892      0.499
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      3.69G      1.124      1.776     0.7619     0.9096        129        512: 100% 473/473 [03:34<00:00,  2.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.23it/s]
#                    all        630      10552      0.883      0.888      0.936      0.775      0.859      0.853       0.89      0.499
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.81G      1.114      1.756     0.7565     0.9069        176        512: 100% 473/473 [03:35<00:00,  2.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  2.94it/s]
#                    all        630      10552      0.872      0.891      0.937      0.777      0.858      0.851      0.894      0.499
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      3.38G      1.111      1.747     0.7495     0.9061         80        512: 100% 473/473 [03:39<00:00,  2.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.02it/s]
#                    all        630      10552      0.876      0.886      0.937      0.778      0.851      0.862      0.892      0.497
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.96G      1.098      1.738     0.7481     0.9048         58        512: 100% 473/473 [03:39<00:00,  2.15it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.37it/s]
#                    all        630      10552       0.87        0.9       0.94      0.778      0.845      0.868      0.895      0.502
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      3.35G      1.096      1.722     0.7418     0.9018        119        512: 100% 473/473 [03:37<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.16it/s]
#                    all        630      10552       0.89      0.882      0.941      0.783      0.867      0.851      0.891        0.5
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      3.18G       1.09       1.73     0.7373     0.9012        182        512: 100% 473/473 [03:32<00:00,  2.23it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.84it/s]
#                    all        630      10552      0.871      0.894      0.939      0.784      0.844       0.87      0.894      0.506
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.79G      1.086      1.724     0.7316     0.9027        179        512: 100% 473/473 [03:36<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.03it/s]
#                    all        630      10552      0.885      0.888      0.942      0.784      0.856       0.86      0.896      0.506
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      3.19G       1.08      1.714     0.7242     0.9001         76        512: 100% 473/473 [03:37<00:00,  2.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:07<00:00,  2.86it/s]
#                    all        630      10552      0.889      0.882      0.942      0.787      0.868      0.849      0.896      0.511
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.72G      1.078      1.705     0.7241     0.8983        162        512: 100% 473/473 [03:35<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.09it/s]
#                    all        630      10552      0.877      0.891      0.939      0.787      0.849      0.863      0.895       0.51
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      3.65G      1.057      1.678     0.7057     0.8957         98        512: 100% 473/473 [03:36<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.26it/s]
#                    all        630      10552       0.88      0.885      0.938      0.783      0.852      0.858       0.89      0.502
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.46G      1.061      1.694     0.7145     0.8959        292        512: 100% 473/473 [03:36<00:00,  2.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.26it/s]
#                    all        630      10552       0.89      0.886      0.943      0.789      0.859      0.851      0.891      0.505
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      3.11G      1.059      1.677     0.7099     0.8941        197        512: 100% 473/473 [03:34<00:00,  2.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.15it/s]
#                    all        630      10552      0.888      0.891      0.944      0.791       0.86       0.86        0.9      0.512
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.84G      1.113      1.816     0.7535     0.9152        130        512: 100% 473/473 [02:00<00:00,  3.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.58it/s]
#                    all        630      10552      0.882      0.892      0.944      0.792       0.86      0.862      0.902      0.519
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.58G      1.087      1.777     0.7447     0.9051         87        512: 100% 473/473 [01:53<00:00,  4.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.65it/s]
#                    all        630      10552      0.888      0.895      0.944      0.794      0.857      0.862      0.896      0.516
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      2.43G      1.083      1.792     0.7481     0.9036        188        512: 100% 473/473 [01:52<00:00,  4.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.54it/s]
#                    all        630      10552      0.894      0.889      0.946      0.799       0.87      0.862      0.904       0.52
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.74G      1.074      1.765     0.7361     0.9014         54        512: 100% 473/473 [01:52<00:00,  4.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.37it/s]
#                    all        630      10552      0.892      0.895      0.946      0.795      0.864      0.861      0.898      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.57G      1.058      1.743     0.7231     0.8993         86        512: 100% 473/473 [01:53<00:00,  4.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:06<00:00,  3.28it/s]
#                    all        630      10552      0.887      0.897      0.946      0.799      0.865      0.865      0.904      0.523
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       46/50       2.6G      1.055      1.751     0.7223     0.8973         45        512: 100% 473/473 [01:52<00:00,  4.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.36it/s]
#                    all        630      10552      0.884        0.9      0.946      0.796      0.851      0.871      0.898      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.74G      1.045       1.72     0.7158     0.8965        242        512: 100% 473/473 [01:52<00:00,  4.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.46it/s]
#                    all        630      10552       0.89      0.899      0.947      0.799      0.859      0.873      0.903      0.521
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       2.7G      1.035      1.708     0.7053     0.8934        174        512: 100% 473/473 [01:52<00:00,  4.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.41it/s]
#                    all        630      10552      0.894      0.892      0.947      0.801      0.868      0.863      0.904      0.521
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.68G       1.03      1.718     0.7083     0.8918         56        512: 100% 473/473 [01:53<00:00,  4.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.36it/s]
#                    all        630      10552      0.894      0.894      0.947      0.802      0.868      0.867      0.905      0.523
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.45G      1.026      1.699     0.7032     0.8918         98        512: 100% 473/473 [01:51<00:00,  4.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:05<00:00,  3.42it/s]
#                    all        630      10552      0.892      0.898      0.947      0.802      0.864      0.865      0.903      0.524
#
# 50 epochs completed in 2.826 hours.
# Optimizer stripped from runs/segment/train/weights/last.pt, 6.8MB
# Optimizer stripped from runs/segment/train/weights/best.pt, 6.8MB
#
# Validating runs/segment/train/weights/best.pt...
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 20/20 [00:11<00:00,  1.76it/s]
#                    all        630      10552      0.892      0.898      0.947      0.803      0.864      0.864      0.903      0.524
#                    C.R        630       3346      0.869      0.862      0.937       0.79      0.885       0.87      0.943      0.592
#                    C.V        630       6442       0.96      0.966      0.989      0.795      0.908       0.91      0.924      0.427
#                    S.P        630        764      0.846      0.866      0.915      0.823      0.799      0.812      0.842      0.552
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/segment/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 1min 37s, sys: 11 s, total: 1min 48s
# Wall time: 3h 40s

# %% [markdown]
# Validate the model

# %%
# !yolo task= segment mode= val model= /content/runs/segment/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/data.yaml
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB_IMG_Aug/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 40/40 [00:18<00:00,  2.20it/s]
#                    all        630      10552      0.892      0.898      0.947      0.803      0.858      0.859      0.896      0.507
#                    C.R        630       3346      0.869      0.862      0.937      0.791      0.883      0.871      0.942      0.575
#                    C.V        630       6442       0.96      0.966      0.989      0.795      0.891      0.895      0.906      0.397
#                    S.P        630        764      0.848      0.868      0.915      0.823      0.799      0.812       0.84      0.549
# Speed: 0.5ms preprocess, 2.9ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to runs/segment/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
