# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 30.0/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2-instance-seg
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2-instance-seg/dataset/1

# %%
# train yolov8n on custom data for 50 epochs
# time its performance
# %%time

# !yolo task=segment mode=train model=yolov8n-seg.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 188MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task= segment mode= val model= /content/runs/segment/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/data.yaml
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Instance_Seg_YoloV8_RGB/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 40/40 [00:11<00:00,  3.35it/s]
# ...

# %% [markdown]
# Testing the model

# %%
# !yolo task=segment mode=predict model= /content/runs/segment/train/weights/best.pt conf=0.25 source= /content/runs/segment/predict
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# YOLOv8n-seg summary (fused): 195 layers, 3258649 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/60 /content/runs/segment/predict/Chlamy0000.jpg: 512x512 15 C.Rs, 11.8ms
# image 2/60 /content/runs/segment/predict/Chlamy0001.jpg: 512x512 22 C.Rs, 8.1ms
# image 3/60 /content/runs/segment/predict/Chlamy0002.jpg: 512x512 35 C.Rs, 7.5ms
# image 4/60 /content/runs/segment/predict/Chlamy0003.jpg: 512x512 21 C.Rs, 8.0ms
# image 5/60 /content/runs/segment/predict/Chlamy0004.jpg: 512x512 26 C.Rs, 7.5ms
# ...
