# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2
#   version: 11
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2/dataset/11

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 75.9MB/s]
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 16.7MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/train/labels... 7550 images, 5 backgrounds, 0 corrupt: 100% 7554/7554 [11:20<00:00, 11.10it/s]
# train: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/valid/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [01:56<00:00,  5.40it/s]
# val: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.26G       1.19      1.357      0.972         30        512: 100% 473/473 [01:01<00:00,  7.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.18it/s]
#                    all        630       9958      0.657      0.731      0.704       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50       2.3G      1.003     0.8215     0.9283         68        512: 100% 473/473 [00:52<00:00,  8.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.84it/s]
#                    all        630       9958      0.669      0.705      0.726      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.69G      0.975     0.7521     0.9251         45        512: 100% 473/473 [00:50<00:00,  9.30it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.14it/s]
#                    all        630       9958      0.687      0.715      0.721      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50       3.4G     0.9465     0.7029      0.917         35        512: 100% 473/473 [00:50<00:00,  9.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.15it/s]
#                    all        630       9958      0.695      0.766      0.765      0.521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      3.03G     0.9147     0.6721     0.9121         10        512: 100% 473/473 [00:50<00:00,  9.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.07it/s]
#                    all        630       9958      0.704      0.745      0.768       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.46G     0.8908     0.6422     0.9053         51        512: 100% 473/473 [00:50<00:00,  9.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.29it/s]
#                    all        630       9958      0.721      0.735      0.755      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         3G     0.8766     0.6298      0.904          4        512: 100% 473/473 [00:51<00:00,  9.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.15it/s]
#                    all        630       9958      0.748      0.749      0.792      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50       2.5G      0.857     0.6108     0.8991         98        512: 100% 473/473 [00:50<00:00,  9.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.96it/s]
#                    all        630       9958      0.684      0.738      0.769      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.58G     0.8466     0.5937     0.8981         20        512: 100% 473/473 [00:50<00:00,  9.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.75it/s]
#                    all        630       9958      0.739      0.769      0.795      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.41G      0.835     0.5811     0.8956          6        512: 100% 473/473 [00:49<00:00,  9.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.80it/s]
#                    all        630       9958      0.701      0.735      0.773      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.43G      0.825     0.5801     0.8923         19        512: 100% 473/473 [00:49<00:00,  9.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.78it/s]
#                    all        630       9958       0.71      0.723      0.777      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.65G     0.8098     0.5649      0.889         30        512: 100% 473/473 [00:49<00:00,  9.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.92it/s]
#                    all        630       9958      0.773      0.793      0.831      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50       2.3G     0.8132     0.5677     0.8906         24        512: 100% 473/473 [00:50<00:00,  9.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.12it/s]
#                    all        630       9958       0.77       0.81      0.838      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.69G     0.8049      0.545     0.8851         20        512: 100% 473/473 [00:50<00:00,  9.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.11it/s]
#                    all        630       9958      0.759      0.785      0.815      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.88G     0.7936     0.5441     0.8853         26        512: 100% 473/473 [00:50<00:00,  9.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.40it/s]
#                    all        630       9958      0.774      0.809      0.837      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.47G     0.7848     0.5401     0.8853         26        512: 100% 473/473 [00:50<00:00,  9.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.30it/s]
#                    all        630       9958      0.784      0.802      0.842      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      3.09G     0.7774     0.5295     0.8829         31        512: 100% 473/473 [00:50<00:00,  9.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.25it/s]
#                    all        630       9958      0.759       0.83      0.845      0.618
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       3.1G     0.7702     0.5309     0.8842         95        512: 100% 473/473 [00:50<00:00,  9.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.45it/s]
#                    all        630       9958      0.773      0.821      0.846      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.76G     0.7694     0.5169      0.877         76        512: 100% 473/473 [00:50<00:00,  9.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.17it/s]
#                    all        630       9958      0.788      0.826      0.856      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.27G     0.7625      0.515     0.8799         25        512: 100% 473/473 [00:49<00:00,  9.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.87it/s]
#                    all        630       9958      0.786      0.821      0.856      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50       2.9G     0.7596     0.5174       0.88         63        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.93it/s]
#                    all        630       9958      0.802      0.818      0.859      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50       2.8G     0.7586     0.5156     0.8788         79        512: 100% 473/473 [00:49<00:00,  9.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.94it/s]
#                    all        630       9958      0.791      0.822      0.858      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.91G     0.7498     0.5074     0.8783         20        512: 100% 473/473 [00:49<00:00,  9.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.92it/s]
#                    all        630       9958      0.787      0.834      0.858      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.74G     0.7461     0.5051     0.8795         31        512: 100% 473/473 [00:49<00:00,  9.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.06it/s]
#                    all        630       9958       0.79      0.831      0.858      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      3.09G     0.7382     0.4979      0.873         57        512: 100% 473/473 [00:49<00:00,  9.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.58it/s]
#                    all        630       9958      0.805      0.826      0.861       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.58G     0.7339     0.4914     0.8711        132        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.47it/s]
#                    all        630       9958      0.803      0.825      0.863      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      2.33G      0.731     0.4894     0.8737        217        512: 100% 473/473 [00:49<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.30it/s]
#                    all        630       9958      0.805      0.812      0.862      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      2.48G     0.7206     0.4832     0.8731         30        512: 100% 473/473 [00:49<00:00,  9.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.42it/s]
#                    all        630       9958      0.801      0.826      0.866      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.37G     0.7227     0.4844     0.8731         13        512: 100% 473/473 [00:49<00:00,  9.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958      0.787      0.835       0.86      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      3.23G     0.7232     0.4808     0.8712        145        512: 100% 473/473 [00:49<00:00,  9.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.74it/s]
#                    all        630       9958      0.808      0.841      0.871      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.89G     0.7174     0.4763     0.8705        104        512: 100% 473/473 [00:49<00:00,  9.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.95it/s]
#                    all        630       9958      0.796      0.843       0.87      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.12G     0.7051     0.4678     0.8695         22        512: 100% 473/473 [00:48<00:00,  9.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.87it/s]
#                    all        630       9958        0.8      0.845      0.873       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.94G     0.7124     0.4739     0.8713         30        512: 100% 473/473 [00:49<00:00,  9.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.96it/s]
#                    all        630       9958      0.816      0.836      0.883      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      2.81G     0.7083     0.4655     0.8652         76        512: 100% 473/473 [00:49<00:00,  9.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.15it/s]
#                    all        630       9958      0.814      0.833      0.881      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.65G     0.7014     0.4612     0.8669         73        512: 100% 473/473 [00:49<00:00,  9.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.41it/s]
#                    all        630       9958      0.808      0.853       0.88      0.671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.68G     0.6944     0.4594      0.866         13        512: 100% 473/473 [00:49<00:00,  9.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.44it/s]
#                    all        630       9958      0.813      0.854      0.888      0.676
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      3.09G     0.6971     0.4577     0.8661         20        512: 100% 473/473 [00:49<00:00,  9.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.57it/s]
#                    all        630       9958      0.805      0.858      0.885      0.678
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      3.05G     0.6908     0.4554      0.863         35        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.37it/s]
#                    all        630       9958      0.812      0.854      0.886      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.51G     0.6864     0.4505     0.8643         57        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.62it/s]
#                    all        630       9958      0.823      0.831      0.879      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.81G     0.6856     0.4464     0.8645         24        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.49it/s]
#                    all        630       9958       0.82       0.84      0.886       0.68
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.49G     0.6762     0.4095     0.8467         40        512: 100% 473/473 [00:53<00:00,  8.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.38it/s]
#                    all        630       9958      0.822      0.851      0.886      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.05G     0.6685     0.4052     0.8472          2        512: 100% 473/473 [00:48<00:00,  9.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.46it/s]
#                    all        630       9958      0.825      0.845      0.887      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.91G     0.6656     0.3985     0.8456         12        512: 100% 473/473 [00:47<00:00,  9.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.06it/s]
#                    all        630       9958      0.811      0.864      0.889       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.13G     0.6642     0.3977     0.8449          8        512: 100% 473/473 [00:47<00:00,  9.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.01it/s]
#                    all        630       9958      0.815      0.859      0.889      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.46G     0.6606     0.3954     0.8437         71        512: 100% 473/473 [00:47<00:00,  9.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.48it/s]
#                    all        630       9958       0.82      0.857      0.894      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.25G     0.6552     0.3895     0.8413         26        512: 100% 473/473 [00:47<00:00,  9.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.62it/s]
#                    all        630       9958      0.829      0.852      0.891      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.95G     0.6503     0.3845     0.8402         20        512: 100% 473/473 [00:47<00:00,  9.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.43it/s]
#                    all        630       9958       0.82      0.867      0.894      0.696
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      2.25G     0.6497      0.383     0.8419         48        512: 100% 473/473 [00:49<00:00,  9.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.76it/s]
#                    all        630       9958      0.829      0.852      0.896      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.48G     0.6436      0.381     0.8398         30        512: 100% 473/473 [00:47<00:00,  9.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.95it/s]
#                    all        630       9958      0.841      0.847      0.897        0.7
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.16G     0.6434     0.3773      0.839         27        512: 100% 473/473 [00:47<00:00,  9.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.15it/s]
#                    all        630       9958      0.844      0.847      0.898      0.702
#
# 50 epochs completed in 0.749 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95):  10% 2/20 [00:00<00:04,  4.26it/s]WARNING ⚠️ NMS time limit 3.600s exceeded
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:10<00:00,  1.98it/s]
#                    all        630       9958      0.843      0.826      0.884       0.69
#                    C.R        630       2715      0.786      0.801       0.86      0.633
#                    C.V        630       6435      0.954      0.904      0.949      0.758
#                    S.P        630        808       0.79      0.774      0.844      0.681
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 7.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 45.4 s, sys: 5.7 s, total: 51.1 s
# Wall time: 59min 59s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/data.yaml
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_BB_Aug/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:14<00:00,  2.73it/s]
#                    all        630       9958      0.844      0.848      0.898      0.705
#                    C.R        630       2715      0.785        0.8      0.859      0.633
#                    C.V        630       6435      0.956      0.969      0.989      0.801
#                    S.P        630        808       0.79      0.775      0.844      0.681
# Speed: 0.3ms preprocess, 1.2ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
