# %% [markdown]
# Trial_5 where C.V = 32,566 C.R = 13,321 S.P = 3,575 (All same image dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch # YOLOv5 implemented using pytorch

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (8 CPUs, 51.0 GB RAM, 29.8/201.2 GB disk)

# %%
from IPython.display import Image #this is to render predictions

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
# %cat /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/data.yaml
# Out:
# train: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/train
# val: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/valid
# test: ../test/images
#
# nc: 3
# names: ['C.R', 'C.V', 'S.P']
#
# roboflow:
#   workspace: microalgae-hbwao
#   project: algae_detection_individual_exp_4-trial2
#   version: 10
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/microalgae-hbwao/algae_detection_individual_exp_4-trial2/dataset/10

# %%
# train yolov8n on custom data for 100 epochs
# time its performance
# %%time

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/data.yaml epochs=50 imgsz=512 batch=16 plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 207MB/s]
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=512, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 34.9MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/train/labels... 7556 images, 7 backgrounds, 0 corrupt: 100% 7560/7560 [13:10<00:00,  9.56it/s]
# train: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/valid/labels... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [01:07<00:00,  9.36it/s]
# val: New cache created: /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 512 train, 512 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.29G      1.915      1.872      1.219        189        512: 100% 473/473 [01:01<00:00,  7.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:04<00:00,  4.05it/s]
#                    all        630       9958      0.662      0.761      0.743      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.32G      1.769      1.446      1.181         94        512: 100% 473/473 [00:51<00:00,  9.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.64it/s]
#                    all        630       9958      0.659      0.719      0.732      0.457
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.98G      1.751      1.375      1.174        191        512: 100% 473/473 [00:50<00:00,  9.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.72it/s]
#                    all        630       9958      0.683      0.675      0.733      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.82G      1.686      1.311      1.157        197        512: 100% 473/473 [00:49<00:00,  9.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.79it/s]
#                    all        630       9958      0.697      0.713       0.77      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.23G      1.643      1.248      1.137        160        512: 100% 473/473 [00:50<00:00,  9.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.76it/s]
#                    all        630       9958      0.719      0.798      0.797      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.12G      1.613      1.203      1.121         94        512: 100% 473/473 [00:49<00:00,  9.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.01it/s]
#                    all        630       9958      0.699      0.772      0.779      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.67G      1.586      1.171      1.107        210        512: 100% 473/473 [00:49<00:00,  9.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.94it/s]
#                    all        630       9958      0.721      0.796      0.802      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.69G      1.559      1.135      1.107        181        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.36it/s]
#                    all        630       9958      0.712      0.802      0.803      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.45G      1.532      1.112      1.095         94        512: 100% 473/473 [00:49<00:00,  9.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.24it/s]
#                    all        630       9958      0.698      0.805      0.801      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.55G      1.517       1.09      1.083        179        512: 100% 473/473 [00:49<00:00,  9.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.97it/s]
#                    all        630       9958      0.766      0.783      0.819      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.64G      1.513      1.086      1.087        165        512: 100% 473/473 [00:49<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.15it/s]
#                    all        630       9958      0.709      0.738      0.785      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.12G      1.495       1.08      1.079        165        512: 100% 473/473 [00:49<00:00,  9.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.37it/s]
#                    all        630       9958      0.754      0.794      0.821      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.46G      1.479      1.061      1.077         95        512: 100% 473/473 [00:49<00:00,  9.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.31it/s]
#                    all        630       9958      0.764      0.809      0.836      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.21G      1.462      1.044      1.067        289        512: 100% 473/473 [00:49<00:00,  9.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.13it/s]
#                    all        630       9958      0.778      0.784      0.836      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.95G      1.448      1.028      1.067        150        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.47it/s]
#                    all        630       9958      0.769      0.805      0.843      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.82G      1.432      1.015      1.065        442        512: 100% 473/473 [00:49<00:00,  9.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958      0.783      0.817      0.844      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.37G      1.432      1.003      1.062        111        512: 100% 473/473 [00:48<00:00,  9.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.31it/s]
#                    all        630       9958       0.78      0.811      0.839      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.73G      1.422      1.001      1.058        115        512: 100% 473/473 [00:48<00:00,  9.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.47it/s]
#                    all        630       9958      0.786      0.811      0.852       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      2.55G      1.404     0.9919      1.056         89        512: 100% 473/473 [00:48<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.96it/s]
#                    all        630       9958      0.784       0.82      0.854      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      2.43G      1.405     0.9879      1.054         85        512: 100% 473/473 [00:48<00:00,  9.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.08it/s]
#                    all        630       9958      0.776      0.823      0.849      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      2.72G      1.389     0.9737      1.045        135        512: 100% 473/473 [00:49<00:00,  9.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.94it/s]
#                    all        630       9958      0.786      0.816      0.849      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      2.63G      1.377     0.9585      1.047         89        512: 100% 473/473 [00:48<00:00,  9.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.87it/s]
#                    all        630       9958      0.812      0.808      0.862      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      2.39G      1.371     0.9532      1.043        122        512: 100% 473/473 [00:48<00:00,  9.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.09it/s]
#                    all        630       9958      0.801      0.822      0.858      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      2.93G      1.352     0.9423      1.037        147        512: 100% 473/473 [00:48<00:00,  9.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630       9958      0.797      0.822      0.856      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      2.22G      1.366     0.9506      1.041        107        512: 100% 473/473 [00:48<00:00,  9.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.41it/s]
#                    all        630       9958      0.805      0.818      0.861      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      2.67G       1.35     0.9373      1.036        142        512: 100% 473/473 [00:48<00:00,  9.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.52it/s]
#                    all        630       9958      0.814      0.804      0.857      0.642
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.87G      1.344     0.9311      1.034        106        512: 100% 473/473 [00:48<00:00,  9.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.61it/s]
#                    all        630       9958      0.777      0.842      0.867      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50       2.5G      1.336     0.9242      1.034         96        512: 100% 473/473 [00:48<00:00,  9.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.41it/s]
#                    all        630       9958      0.789      0.824      0.858      0.645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      2.04G      1.328     0.9128      1.029        117        512: 100% 473/473 [00:48<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:02<00:00,  6.72it/s]
#                    all        630       9958      0.807      0.825      0.863      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      2.59G      1.322     0.9013      1.022        222        512: 100% 473/473 [00:48<00:00,  9.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.32it/s]
#                    all        630       9958      0.814      0.827      0.869      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      2.23G      1.312     0.9023      1.023        123        512: 100% 473/473 [00:48<00:00,  9.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.65it/s]
#                    all        630       9958      0.791      0.841      0.866      0.659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      2.16G      1.306     0.8955      1.024         89        512: 100% 473/473 [00:49<00:00,  9.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:02<00:00,  6.74it/s]
#                    all        630       9958      0.818      0.827      0.875      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      2.23G      1.299     0.8895      1.023        153        512: 100% 473/473 [00:48<00:00,  9.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.36it/s]
#                    all        630       9958      0.817      0.834      0.877      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50       2.3G      1.297     0.8872       1.02        192        512: 100% 473/473 [00:48<00:00,  9.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.97it/s]
#                    all        630       9958      0.814      0.836      0.876      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      2.97G      1.295     0.8816      1.016        110        512: 100% 473/473 [00:48<00:00,  9.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  5.99it/s]
#                    all        630       9958      0.824      0.833      0.874       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      2.52G      1.275     0.8719      1.015        118        512: 100% 473/473 [00:48<00:00,  9.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.26it/s]
#                    all        630       9958      0.809      0.843      0.876      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      2.29G      1.277     0.8706      1.013         97        512: 100% 473/473 [00:48<00:00,  9.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.09it/s]
#                    all        630       9958      0.825      0.828      0.876      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      2.57G      1.263     0.8623      1.014        169        512: 100% 473/473 [00:48<00:00,  9.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.14it/s]
#                    all        630       9958      0.827      0.824      0.879      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      2.53G      1.265     0.8549      1.008        176        512: 100% 473/473 [00:48<00:00,  9.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.30it/s]
#                    all        630       9958      0.819      0.847      0.883       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      2.08G      1.264     0.8522      1.007        274        512: 100% 473/473 [00:48<00:00,  9.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.46it/s]
#                    all        630       9958      0.825       0.84      0.881      0.673
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      2.24G      1.293      0.861      1.018        140        512: 100% 473/473 [00:52<00:00,  9.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.11it/s]
#                    all        630       9958      0.834      0.832       0.88      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      2.23G      1.273     0.8393      1.007         69        512: 100% 473/473 [00:46<00:00, 10.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.04it/s]
#                    all        630       9958      0.841       0.83      0.888      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50       2.2G      1.267     0.8384      1.006        191        512: 100% 473/473 [00:47<00:00,  9.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.52it/s]
#                    all        630       9958      0.837      0.836      0.886      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      2.42G      1.248     0.8253          1         72        512: 100% 473/473 [00:47<00:00,  9.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.67it/s]
#                    all        630       9958      0.828      0.846      0.888      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      2.16G      1.241     0.8179     0.9955         80        512: 100% 473/473 [00:47<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.59it/s]
#                    all        630       9958      0.831      0.846      0.892      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      2.19G      1.222     0.8084     0.9928         50        512: 100% 473/473 [00:47<00:00, 10.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.27it/s]
#                    all        630       9958      0.814      0.863      0.888      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      2.18G      1.224     0.8031     0.9933        182        512: 100% 473/473 [00:47<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.12it/s]
#                    all        630       9958      0.824      0.855      0.888       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       2.6G      1.217     0.8034     0.9909        172        512: 100% 473/473 [00:47<00:00, 10.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.19it/s]
#                    all        630       9958      0.836      0.834      0.889      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      2.57G      1.207     0.7945     0.9884         80        512: 100% 473/473 [00:48<00:00,  9.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.43it/s]
#                    all        630       9958      0.837       0.84      0.891      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      2.18G      1.194     0.7884     0.9867         39        512: 100% 473/473 [00:48<00:00,  9.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:03<00:00,  6.50it/s]
#                    all        630       9958      0.831      0.847       0.89      0.693
#
# 50 epochs completed in 0.737 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 20/20 [00:11<00:00,  1.77it/s]
#                    all        630       9958      0.831      0.847       0.89      0.693
#                    C.R        630       2715      0.772      0.781       0.85      0.623
#                    C.V        630       6435      0.954      0.966      0.989       0.79
#                    S.P        630        808      0.768      0.795       0.83      0.666
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train
# CPU times: user 44.4 s, sys: 5.56 s, total: 49.9 s
# Wall time: 1h 18s

# %% [markdown]
# Validate the model

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model= /content/runs/detect/train/weights/best.pt data= /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/data.yaml
# Out:
# Ultralytics YOLOv8.2.16 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Experiment_4_Yolo_V8/Algae_Detection_YoloV8_RGB_IMG_Aug/valid/labels.cache... 630 images, 0 backgrounds, 0 corrupt: 100% 630/630 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 40/40 [00:11<00:00,  3.47it/s]
#                    all        630       9958      0.831      0.848       0.89      0.695
#                    C.R        630       2715      0.772      0.782      0.851      0.623
#                    C.V        630       6435      0.953      0.967      0.989      0.797
#                    S.P        630        808      0.767      0.795       0.83      0.665
# Speed: 0.3ms preprocess, 1.3ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# Testing the model

# %%
# !yolo task=/content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect mode=predict model= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/detect/train/weights/best.pt conf=0.25 source= /content/drive/MyDrive/Experiment_4_Yolo_V8/Trained_Obj_Detection/runs_YoloV8n_RGB_ObjDetection/predict
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
from IPython.display import Image, display
import glob

# Get a list of all JPG files in the 'exp' directory
image_files = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

# Display all images
for image_file in image_files:
    display(Image(filename=image_file))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
